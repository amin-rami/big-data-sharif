# %% [markdown]
# # Mohammad Amin Rami
# # 98101588
# # Big Data HW1 Question 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('MOVIE_IMDB.csv')

# %%
print('The number NaN values of each row:')
df.apply(lambda row: row.isna().sum(), axis=1)
# Out:
# The number NaN values of each row:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
print('The number NaN values of each column:')
df.isna().sum()
# Out:
# The number NaN values of each column:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# ...

# %%
print('Percentage of NaN values in each column:')
round(df.isna().sum()/df.shape[0]*100, 2)
# Out:
# Percentage of NaN values in each column:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.24
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# ...

# %%
columns_to_delete = [
    'color',
    'director_facebook_likes',
    'actor_1_facebook_likes',
    'actor_2_facebook_likes',
    'actor_3_facebook_likes',
    'actor_2_name',
    'cast_total_facebook_likes',
    'actor_3_name',
    'duration',
    'facenumber_in_poster',
    'content_rating',
    'country',
    'movie_imdb_link',
    'aspect_ratio',
    'plot_keywords',
]

df.drop(columns_to_delete, axis=1, inplace=True)
df
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4           Doug Walker                     NaN          NaN
# ...                 ...                     ...          ...
# 5038        Scott Smith                     1.0          NaN
# 5039                NaN                    43.0          NaN
# 5040   Benjamin Roberds                    13.0          NaN
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
print('Percentage of NaN values in each column:')
round(df.isna().sum()/df.shape[0]*100, 2)
# Out:
# Percentage of NaN values in each column:
# director_name              2.06
# num_critic_for_reviews     0.99
# gross                     17.53
# genres                     0.00
# actor_1_name               0.14
# movie_title                0.00
# num_voted_users            0.00
# num_user_for_reviews       0.42
# language                   0.24
# budget                     9.76
# title_year                 2.14
# imdb_score                 0.00
# movie_facebook_likes       0.00
# dtype: float64

# %%
df.dropna(subset=['gross', 'budget'], inplace=True)

# %%
df['language'] = df['language'].fillna('English')

# %%
print('Percentage of NaN values in each column:')
round(df.isna().sum()/df.shape[0]*100, 2)
df
# Out:
# Percentage of NaN values in each column:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
print('dropping duplicates')
df.drop_duplicates(inplace=True)
df
# Out:
# dropping duplicates
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
df['profit'] = df['gross'] - df['budget']
df
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
df_positive_profit = df[df['profit'] >= 0]
df_negative_profit = df[df['profit'] < 0]

fig = plt.figure(figsize=(12, 3))
ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(df_positive_profit['budget'], df_positive_profit['profit'], 'bo')
ax1.set_xlabel('budget')
ax1.set_ylabel('profit')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_title('budget vs profit plot for movies with positive profit')
ax1.grid()


fig = plt.figure(figsize=(12, 3))
ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(df_negative_profit['budget'], df_negative_profit['profit'], 'bo')
ax2.set_xlabel('budget')
ax2.set_ylabel('profit')
ax2.set_xlim([0, 2e8])
ax2.set_ylim([-2e8, 0])
ax2.set_title('budget vs profit plot for movies with negative profit')
ax2.grid()

# %%
print('Movies with top profit')
df.sort_values('profit', ascending=False).head(10).reset_index()[['movie_title', 'profit']]
# Out:
# Movies with top profit
#                                   movie_title       profit
# 0                                     Avatar   523505847.0
# 1                             Jurassic World   502177271.0
# 2                                    Titanic   458672302.0
# 3         Star Wars: Episode IV - A New Hope   449935665.0
# 4                 E.T. the Extra-Terrestrial   424449459.0
# 5                               The Avengers   403279547.0
# 6                              The Lion King   377783777.0
# 7  Star Wars: Episode I - The Phantom Menace   359544677.0
# 8                            The Dark Knight   348316061.0
# 9                           The Hunger Games   329999255.0

# %%
print('list of all unique genres')
df['genres'].unique()
# Out:
# list of all unique genres
# array(['Action|Adventure|Fantasy|Sci-Fi', 'Action|Adventure|Fantasy',
#        'Action|Adventure|Thriller', 'Action|Thriller',
#        'Action|Adventure|Sci-Fi', 'Action|Adventure|Romance',
#        'Adventure|Animation|Comedy|Family|Fantasy|Musical|Romance',
#        'Adventure|Family|Fantasy|Mystery', 'Action|Adventure',
#        'Action|Adventure|Western', 'Action|Adventure|Family|Fantasy',
#        'Action|Adventure|Comedy|Family|Fantasy|Sci-Fi',
#        'Adventure|Fantasy', 'Action|Adventure|Drama|History',
#        'Adventure|Family|Fantasy', 'Action|Adventure|Drama|Romance',
#        'Drama|Romance', 'Action|Adventure|Sci-Fi|Thriller',
#        'Action|Adventure|Fantasy|Romance',
#        'Action|Adventure|Fantasy|Sci-Fi|Thriller',
#        'Adventure|Animation|Comedy|Family|Fantasy',
#        'Adventure|Animation|Comedy|Family|Sport', 'Action|Crime|Thriller',
#        'Action|Adventure|Horror|Sci-Fi|Thriller',
# ...

# %%
result = df.groupby('genres').aggregate({'movie_title': 'nunique', 'profit': 'mean'})
result.rename(columns={'movie_title': 'movie count', 'profit': 'mean profit'})
# Out:
#                                                     movie count   mean profit
# genres
# Action                                                        6 -3.264576e+07
# Action|Adventure                                              9  6.507458e+07
# Action|Adventure|Animation|Comedy|Crime|Family|...            1 -5.640309e+07
# Action|Adventure|Animation|Comedy|Drama|Family|...            2  5.323508e+06
# Action|Adventure|Animation|Comedy|Family                      5  4.714108e+07
# ...                                                         ...           ...
# Romance|Sci-Fi|Thriller                                       1  1.225332e+07
# Sci-Fi                                                        1 -2.318050e+05
# Sci-Fi|Thriller                                               7  2.065219e+06
# Thriller                                                      3 -5.618203e+05
# Western                                                       3  1.320459e+07
#
# [762 rows x 2 columns]

# %%
indices = df['title_year'].between(2007, 2015, inclusive='both') & df['imdb_score'].between(7.5, 8.5, inclusive='both')
df.loc[indices, 'genres']
# Out:
# 0                         Action|Adventure|Fantasy|Sci-Fi
# 3                                         Action|Thriller
# 7       Adventure|Animation|Comedy|Family|Fantasy|Musi...
# 8                                 Action|Adventure|Sci-Fi
# 9                        Adventure|Family|Fantasy|Mystery
#                               ...
# 4748                                    Documentary|Sport
# 4890                                          Documentary
# 4904                            Documentary|History|Music
# 4922                                        Drama|Romance
# 4931                                  Drama|Music|Romance
# Name: genres, Length: 212, dtype: object

# %%
fig = plt.figure(figsize=(12, 3))

ax1 = fig.add_subplot(1, 2, 1)
ax1.scatter(df['num_voted_users'], df['gross'], edgecolors='black')
ax1.set_yscale('log')
ax1.set_xscale('log')
ax1.set_xlabel('number of voted users')
ax1.set_ylabel('gross')
ax1.grid()

ax2 = fig.add_subplot(1, 2, 2)
ax2.scatter(df['imdb_score'], df['gross'], edgecolors='black')
ax2.set_yscale('log')
ax2.set_xlabel('IMDB score')
ax2.set_ylabel('gross')
ax2.grid()
